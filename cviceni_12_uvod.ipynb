# %%
print("ahoj, jak je ")
# Out:
# ahoj, jak je

# %% [markdown]
# # Moje první analýza
#
# Tento notebook procvičuje práci s Jupyter Notebooky, numpy a matplotlib.

# %%
jmeno = "Jupyter"
verze = 4.2
verze

# %%
len?

# %%
# !uv pip list

# %%
x = 42

# %%
print(x)
